# %%
import numpy as np
import os

# %%
# Print current directory
print(os.getcwd())
# Out:
# /Users/finnferchau/dev/ghostLink/notebooks

# %%
# Load the waveform data
waveform_data = np.load('../data/analog_frames/frame_000000.npz')

# Extract the waveform and metadata
waveform = waveform_data['waveform']

waveform.shape
# Out:
# (1820000,)
